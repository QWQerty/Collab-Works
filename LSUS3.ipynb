# %%
import spacy

# %%
from spacy import displacy

# %%
# !python3 -m spacy download ru_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 55.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 58.2 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("ru_core_news_sm")
doc = nlp("Снижение вероятности воздействия электрическим током на случайный биообъект.")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.dep_)
# Out:
# Снижение снижение NOUN ROOT
# вероятности вероятность NOUN nmod
# воздействия воздействие NOUN nmod
# электрическим электрический ADJ amod
# током ток NOUN nmod
# на на ADP case
# случайный случайный ADJ amod
# биообъект биообъект NOUN nmod
# . . PUNCT punct

# %%
def get_locs(doc):
    entities = []

    for ent in doc.ents:
        if ent.label_ == 'LOC':
            entities += [ent]

    doc.ents = entities
    return doc

# %%
TEXT = 'Посол Мирошник рассказал о последствиях попыток влияния на выборы в России.'

# %%
nlp = spacy.load("ru_core_news_sm")
nlp.vocab
doc = nlp(TEXT)
doc = get_locs(doc)
displacy.serve(doc, style="ent")
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/displacy/__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="ru">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">Посол Мирошник рассказал о последствиях попыток влияния на выборы в
# ...

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 47.2 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from spacy import displacy

TEXT = """ipsum dolor sit amet, May 10, 2024, at 6 pm consectetur adipiscing elit 16:30 pm.
lacus felis, tempus  dignissim pretium, 08.21.2023"""
nlp = spacy.load("en_core_web_sm")
doc = nlp(TEXT)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ipsum dolor sit amet,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 10, 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6 pm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  consectetur adipiscing elit
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16:30 pm
# ...

# %%
# !pip install natasha
# !pip install yargy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 34.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 7.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 80.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=2ca202185b9aa017a010db7b81b023d7991d8fe8452e9f1651b4078da9ef3864
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# ...
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26096 sha256=e71507a425c9967f3f3174e4ca97d197efbbc2980051900925db0aefdb2d750b
#   Stored in directory: /root/.cache/pip/wheels/fa/80/8c/43488a924a046b733b64de3fac99252674c892a4c3801c0a61
# Successfully built docopt intervaltree
# ...

# %%
from natasha import (
    Segmenter,
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    Doc
)

segmenter = Segmenter()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)

text = "Снижение вероятности воздействия электрическим током на случайный биообъект."
doc = Doc(text)

doc.segment(segmenter)
doc.tag_morph(morph_tagger)
doc.parse_syntax(syntax_parser)

sent = doc.sents[0]
sent.morph.print()

sent.syntax.print()
# Out:
#             Снижение NOUN|Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing
#          вероятности NOUN|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
#          воздействия NOUN|Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
#        электрическим ADJ|Case=Ins|Degree=Pos|Gender=Masc|Number=Sing
#                током NOUN|Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing
#                   на ADP
#            случайный ADJ|Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
#            биообъект NOUN|Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
#                    . PUNCT
#        Снижение
#     ┌─ вероятности
# ┌─┌─└► воздействия   nmod
# │ │ ┌► электрическим amod
# │ └►└─ током         nmod
# │ ┌──► на            case
# │ │ ┌► случайный     amod
# └►└─└─ биообъект     nmod
#        .

# %%
from natasha import (
    Segmenter,
    NewsEmbedding,
    NewsNERTagger,
    Doc
)

segmenter = Segmenter()

emb = NewsEmbedding()

text = "Программу назвали «Yandex», название придумали Илья Сегалович, директор"
doc = Doc(text)

doc.segment(segmenter)

ner_tagger = NewsNERTagger(emb)
doc.tag_ner(ner_tagger)
doc.ner.print()
# Out:
# Программу назвали «Yandex», название придумали Илья Сегалович,
#                                                PER───────────
# директор

# %%
from yargy import Parser, rule, and_, not_, or_
from yargy.interpretation import fact
from yargy.predicates import gram

Name = fact(
    'Name',
    ['first', 'last']
)

FIRST = gram('Name').interpretation(
    Name.first.inflected()
)

LAST = gram('Surn').interpretation(
    Name.last.inflected()
)

NAME = or_(
    rule(
        FIRST,
        LAST
    ),
    rule(
        LAST,
        FIRST
    )
).interpretation(
    Name
)

parser = Parser(NAME)
text = '''
... с улицы Грибоедова Антон свернул на ...
... Бушуева Вячеслава и Бушуеву Веру ...
'''

for match in parser.findall(text):
    print(match.fact)
# Out:
# Name(first='антон', last='грибоедов')
# Name(first='вячеслав', last='бушуев')
# Name(first='вера', last='бушуев')

# %%
from yargy.relations import gnc_relation

gnc = gnc_relation()  # согласование по gender, number и case (падежу, числу и роду)

Name = fact(
    'Name',
    ['first', 'last']
)

FIRST = gram('Name').interpretation(
    Name.first.inflected()
).match(gnc)

LAST = gram('Surn').interpretation(
    Name.last.inflected()
).match(gnc)

NAME = or_(
    rule(
        FIRST,
        LAST
    ),
    rule(
        LAST,
        FIRST
    )
).interpretation(
    Name
)

parser = Parser(NAME)
text = '''
... с улицы Грибоедова Антон свернул на ...
... Бушуева Вячеслава и Бушуеву Веру ...
'''

for match in parser.findall(text):
    print(match.fact)
# Out:
# Name(first='вячеслав', last='бушуев')
# Name(first='вера', last='бушуева')
